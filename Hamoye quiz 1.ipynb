# %% [markdown]
# *Here below are some of the result of the hamoye quiz done. I deleted many of the lines containing the results due to the short quiz time in a bid to ensure I completed the assessment. All the codes below are workings of mine and were done during the quiz time frame. Unfortunately, I could not get assess to the quiz questions afterwards to properly re-code and present the results properly.*

# %%
import pandas as pd #importing pandas library

# %%
data = pd.read_csv('FoodBalanceSheets_E_Africa_NOFLAG.csv', encoding='latin-1') #reading data from csv
data.head()
# Out:
#    Area Code     Area  Item Code         Item  Element Code  \
# 0          4  Algeria       2501   Population           511
# 1          4  Algeria       2501   Population          5301
# 2          4  Algeria       2901  Grand Total           664
# 3          4  Algeria       2901  Grand Total           674
# 4          4  Algeria       2901  Grand Total           684
#
#                                   Element             Unit     Y2014  \
# 0           Total Population - Both sexes     1000 persons  38924.00
# 1                Domestic supply quantity      1000 tonnes      0.00
# 2           Food supply (kcal/capita/day)  kcal/capita/day   3377.00
# 3  Protein supply quantity (g/capita/day)     g/capita/day     94.90
# 4      Fat supply quantity (g/capita/day)     g/capita/day     80.06
#
#       Y2015     Y2016     Y2017     Y2018
# 0  39728.00  40551.00  41389.00  42228.00
# 1      0.00      0.00      0.00      0.00
# 2   3379.00   3372.00   3341.00   3322.00
# ...

# %%
df = data[['Element Code', 'Y2014', 'Y2015','Y2016', 'Y2017','Y2018']]
df.corr()
# Out:
#               Element Code     Y2014     Y2015     Y2016     Y2017     Y2018
# Element Code      1.000000  0.024457  0.023889  0.023444  0.024254  0.024279
# Y2014             0.024457  1.000000  0.994647  0.996081  0.995230  0.994872
# Y2015             0.023889  0.994647  1.000000  0.995739  0.988048  0.988208
# Y2016             0.023444  0.996081  0.995739  1.000000  0.992785  0.992757
# Y2017             0.024254  0.995230  0.988048  0.992785  1.000000  0.998103
# Y2018             0.024279  0.994872  0.988208  0.992757  0.998103  1.000000

# %%
data['Element'].unique()
# Out:
# array(['Total Population - Both sexes', 'Domestic supply quantity',
#        'Food supply (kcal/capita/day)',
#        'Protein supply quantity (g/capita/day)',
#        'Fat supply quantity (g/capita/day)', 'Production',
#        'Import Quantity', 'Stock Variation', 'Export Quantity', 'Feed',
#        'Seed', 'Losses', 'Processing', 'Other uses (non-food)',
#        'Residuals', 'Food', 'Food supply quantity (kg/capita/yr)',
#        'Tourist consumption'], dtype=object)

# %%
df = data[data['Area'] == 'Algeria']
df = df[df['Element'] == 'Import Quantity']
df.head()
# Out:
#       Area Code     Area  Item Code           Item  Element Code  \
# 1308          4  Algeria       2899  Miscellaneous          5142
# 1309          4  Algeria       2899  Miscellaneous           645
# 1310          4  Algeria       2899  Miscellaneous           664
# 1311          4  Algeria       2899  Miscellaneous           674
# 1312          4  Algeria       2899  Miscellaneous           684
#
#                                      Element             Unit  Y2014  Y2015  \
# 1308                                    Food      1000 tonnes  75.00  77.00
# 1309     Food supply quantity (kg/capita/yr)               kg   1.93   1.93
# 1310           Food supply (kcal/capita/day)  kcal/capita/day   2.00   2.00
# 1311  Protein supply quantity (g/capita/day)     g/capita/day   0.06   0.06
# 1312      Fat supply quantity (g/capita/day)     g/capita/day   0.03   0.03
#
#       Y2016  Y2017  Y2018
# 1308  78.00  80.00  82.00
# 1309   1.93   1.93   1.93
# 1310   2.00   2.00   2.00
# ...

# %%
data[['Y2014, 'Y2018']]

# %%
df=data['Element'].value_counts()
df
# Out:
# Domestic supply quantity                  5295
# Import Quantity                           5139
# Protein supply quantity (g/capita/day)    5023
# Fat supply quantity (g/capita/day)        5023
# Food supply (kcal/capita/day)             5014
# Food                                      4941
# Food supply quantity (kg/capita/yr)       4905
# Residuals                                 4655
# Export Quantity                           4403
# Stock Variation                           4232
# Production                                3881
# Processing                                2010
# Losses                                    2009
# Other uses (non-food)                     1732
# Feed                                      1319
# Seed                                       762
# Tourist consumption                        555
# Total Population - Both sexes               45
# Name: Element, dtype: int64

# %%
df=data.groupby(by='Element').sum()
df
# Out:
#                                         Area Code  Item Code  Element Code  \
# Element
# Domestic supply quantity                   708993   14197445      28068795
# Export Quantity                            599910   11840553      26026133
# Fat supply quantity (g/capita/day)         675050   13535000       3435732
# Feed                                       176272    3538507       7282199
# Food                                       663295   13285035      25406622
# Food supply (kcal/capita/day)              674057   13511060       3329296
# Food supply quantity (kg/capita/yr)        658446   13185401       3163725
# Import Quantity                            688174   13795966      28834929
# Losses                                     274353    5424803      10292107
# Other uses (non-food)                      235554    4729749       8926728
# Processing                                 271940    5350416      10313310
# ...
